# %%
import tensorflow as tf
physical_devices = tf.config.list_physical_devices()
tf.config.experimental.set_memory_growth(physical_devices[3], True)

# %%
from tensorflow.keras.layers import Dense,Dropout,Conv2D,Flatten,MaxPooling2D
from tensorflow.keras.models import Sequential
from collections import deque
import numpy as np
import gym
import random
import os
from tensorflow.keras.optimizers import Adam

# %%
output_dir = os.getcwd()

memory_size = 8_000
gamma = 0.9995
learning_rate= 0.001
mini_batch_size = 32

state_size = (210,160,1)
n_episodes = 10_000

epsilon_max = 0.75
epsilon_min = 0.1

# %%
env = gym.make("Breakout-v0")
action_size = env.action_space.n
action_size
# Out:
# 4

# %%
def process(state1,state2,state3,state4):
    
    def pre(state):
        s1 = state.astype('float')
        s2 = s1/255
        s2 = s2[30:200, 0:160]
        s3 = tf.image.resize(s2, (84, 84))
        s4 = tf.image.rgb_to_grayscale(s3)
        
        return s4
    
    st1 = pre(state1)
    st2 = pre(state2)
    st3 = pre(state3)
    st4 = pre(state4)
    
    states =  np.array(tf.concat((st1,st2,st3,st4),axis=2))
    
    states =  np.expand_dims(states,axis=0)
    
    return states

# %%
class DQNAgent:
  def __init__(self,memory_size,action_size):
    self.action_size=action_size
    self.gamma = 0.99
    self.epsilon = 1
    self.epsilon_decay = 0.999999
    self.epsilon_min = 0.1
    self.action_model  = self.build_model()
    self.target_model =  self.build_model()
    self.target_model.set_weights(self.action_model.get_weights())
    self.swap_model = self.build_model()
    self.memory = deque()   
    self.learning_rate = learning_rate

  def build_model(self):
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(8,8),strides=4, activation='relu', input_shape=(84,84,4)))
    model.add(Conv2D(64, kernel_size=(4,4),strides=2, activation='relu'))
    model.add(Conv2D(64, kernel_size=(3,3), strides = 1, activation='relu'))
    model.add(Flatten())
    model.add(Dense(512,activation='relu'))
    model.add(Dense(action_size,activation='linear'))
    model.compile(loss = tf.keras.losses.Huber(),optimizer = tf.keras.optimizers.Adam(lr = 0.00025))
    return model

  def act(self,state, epsilon = epsilon_min):
    if np.random.random()<=epsilon:
        return random.randrange(self.action_size)
    else:
        act_value  = self.action_model.predict(state)
        return np.argmax(act_value[0])

  def load(self,name):
    self.action_model.load_weights(name)
    self.target_model.load_weights(name)

# %%
agent = DQNAgent(memory_size,action_size)
agent.load(output_dir + '/' + 'Breakout'+ '.hdf5')

# %%
def test():
    done = False
    states = deque()
    env.reset()
    time_step_count = 0
    for i in range(4):
        init_state = env.step(random.randrange(action_size))
        states.append(init_state[0])
    updated_states = states.copy()
    current_states = process(states[0],states[1],states[2],states[3])

    for episode in range(100):
        env.reset()
        cum_reward=0
        for time_step in range(5000):
            action = agent.act(current_states)
            next_state,reward,done,_=env.step(action)
            env.render()
            updated_states.popleft()
            updated_states.append(next_state)
            new_states = process(updated_states[0],updated_states[1],updated_states[2],updated_states[3])
            
            reward = reward if not done else -20
            cum_reward +=reward
            del current_states
            current_states =  new_states.copy()
            del new_states
            
            if time_step_count <2000:
                print(f"Time Step:{time_step_count}, Action: {action}, Reward: {reward}")
            
            time_step_count += 1
            
            if done:
                
                print("time step: {}, average reward: {}, episode: {}".format(time_step_count, cum_reward ,episode))
                break
        
    env.close()

# %%
test()
# Out:
# Time Step:0, Action: 0, Reward: 0.0
# Time Step:1, Action: 3, Reward: 0.0
# Time Step:2, Action: 3, Reward: 0.0
# Time Step:3, Action: 2, Reward: 0.0
# Time Step:4, Action: 1, Reward: 0.0
# Time Step:5, Action: 0, Reward: 0.0
# Time Step:6, Action: 2, Reward: 0.0
# Time Step:7, Action: 0, Reward: 0.0
# Time Step:8, Action: 0, Reward: 0.0
# Time Step:9, Action: 0, Reward: 0.0
# Time Step:10, Action: 3, Reward: 0.0
# Time Step:11, Action: 0, Reward: 0.0
# Time Step:12, Action: 0, Reward: 0.0
# Time Step:13, Action: 2, Reward: 0.0
# Time Step:14, Action: 3, Reward: 0.0
# Time Step:15, Action: 2, Reward: 0.0
# Time Step:16, Action: 3, Reward: 0.0
# Time Step:17, Action: 3, Reward: 0.0
# Time Step:18, Action: 2, Reward: 0.0
# Time Step:19, Action: 2, Reward: 0.0
# Time Step:20, Action: 2, Reward: 0.0
# Time Step:21, Action: 2, Reward: 0.0
# Time Step:22, Action: 2, Reward: 0.0
# Time Step:23, Action: 2, Reward: 0.0
# Time Step:24, Action: 0, Reward: 0.0
# Time Step:25, Action: 0, Reward: 0.0
# Time Step:26, Action: 3, Reward: 0.0
# Time Step:27, Action: 3, Reward: 0.0
# Time Step:28, Action: 0, Reward: 0.0
# Time Step:29, Action: 0, Reward: 0.0
# Time Step:30, Action: 2, Reward: 0.0
# Time Step:31, Action: 2, Reward: 0.0
# Time Step:32, Action: 3, Reward: 0.0
# Time Step:33, Action: 2, Reward: 0.0
# Time Step:34, Action: 0, Reward: 0.0
# Time Step:35, Action: 2, Reward: 0.0
# Time Step:36, Action: 2, Reward: 0.0
# Time Step:37, Action: 0, Reward: 0.0
# Time Step:38, Action: 2, Reward: 0.0
# Time Step:39, Action: 2, Reward: 0.0
# Time Step:40, Action: 2, Reward: 0.0
# Time Step:41, Action: 2, Reward: 0.0
# Time Step:42, Action: 0, Reward: 0.0
# Time Step:43, Action: 2, Reward: 1.0
# Time Step:44, Action: 3, Reward: 0.0
# Time Step:45, Action: 3, Reward: 0.0
# Time Step:46, Action: 0, Reward: 0.0
# Time Step:47, Action: 0, Reward: 0.0
# Time Step:48, Action: 0, Reward: 0.0
# Time Step:49, Action: 3, Reward: 0.0
# Time Step:50, Action: 3, Reward: 0.0
# Time Step:51, Action: 3, Reward: 0.0
# Time Step:52, Action: 0, Reward: 0.0
# Time Step:53, Action: 2, Reward: 0.0
# Time Step:54, Action: 0, Reward: 0.0
# Time Step:55, Action: 0, Reward: 0.0
# Time Step:56, Action: 0, Reward: 0.0
# Time Step:57, Action: 0, Reward: 0.0
# Time Step:58, Action: 0, Reward: 0.0
# Time Step:59, Action: 1, Reward: 0.0
# Time Step:60, Action: 0, Reward: 0.0
# Time Step:61, Action: 3, Reward: 0.0
# Time Step:62, Action: 3, Reward: 0.0
# Time Step:63, Action: 3, Reward: 0.0
# Time Step:64, Action: 3, Reward: 0.0
# Time Step:65, Action: 3, Reward: 0.0
# Time Step:66, Action: 1, Reward: 0.0
# Time Step:67, Action: 1, Reward: 0.0
# Time Step:68, Action: 1, Reward: 0.0
# Time Step:69, Action: 3, Reward: 0.0
# Time Step:70, Action: 3, Reward: 0.0
# Time Step:71, Action: 3, Reward: 0.0
# Time Step:72, Action: 1, Reward: 0.0
# Time Step:73, Action: 1, Reward: 0.0
# Time Step:74, Action: 1, Reward: 0.0
# Time Step:75, Action: 0, Reward: 0.0
# Time Step:76, Action: 0, Reward: 0.0
# Time Step:77, Action: 0, Reward: 0.0
# Time Step:78, Action: 0, Reward: 0.0
# Time Step:79, Action: 0, Reward: 0.0
# Time Step:80, Action: 2, Reward: 0.0
# Time Step:81, Action: 3, Reward: 0.0
# Time Step:82, Action: 2, Reward: 0.0
# Time Step:83, Action: 0, Reward: 0.0
# Time Step:84, Action: 0, Reward: 0.0
# Time Step:85, Action: 0, Reward: 0.0
# Time Step:86, Action: 3, Reward: 0.0
# Time Step:87, Action: 3, Reward: 0.0
# Time Step:88, Action: 3, Reward: 0.0
# Time Step:89, Action: 3, Reward: 0.0
# Time Step:90, Action: 3, Reward: 0.0
# Time Step:91, Action: 3, Reward: 0.0
# Time Step:92, Action: 3, Reward: 0.0
# Time Step:93, Action: 1, Reward: 0.0
# Time Step:94, Action: 3, Reward: 0.0
# Time Step:95, Action: 3, Reward: 0.0
# Time Step:96, Action: 3, Reward: 0.0
# Time Step:97, Action: 3, Reward: 0.0
# Time Step:98, Action: 3, Reward: 0.0
# Time Step:99, Action: 3, Reward: 0.0
# Time Step:100, Action: 3, Reward: 0.0
# Time Step:101, Action: 3, Reward: 0.0
# Time Step:102, Action: 3, Reward: 0.0
# Time Step:103, Action: 0, Reward: 0.0
# Time Step:104, Action: 2, Reward: 0.0
# Time Step:105, Action: 0, Reward: 0.0
# Time Step:106, Action: 0, Reward: 0.0
# Time Step:107, Action: 0, Reward: 0.0
# Time Step:108, Action: 3, Reward: 0.0
# Time Step:109, Action: 0, Reward: 0.0
# Time Step:110, Action: 0, Reward: 0.0
# Time Step:111, Action: 0, Reward: 0.0
# Time Step:112, Action: 0, Reward: 0.0
# Time Step:113, Action: 2, Reward: 0.0
# Time Step:114, Action: 0, Reward: 0.0
# Time Step:115, Action: 2, Reward: 0.0
# Time Step:116, Action: 2, Reward: 0.0
# Time Step:117, Action: 0, Reward: 0.0
# Time Step:118, Action: 2, Reward: 1.0
# Time Step:119, Action: 0, Reward: 0.0
# Time Step:120, Action: 0, Reward: 0.0
# Time Step:121, Action: 0, Reward: 0.0
# Time Step:122, Action: 0, Reward: 0.0
# Time Step:123, Action: 0, Reward: 0.0
# Time Step:124, Action: 0, Reward: 0.0
# Time Step:125, Action: 0, Reward: 0.0
# Time Step:126, Action: 0, Reward: 0.0
# Time Step:127, Action: 0, Reward: 0.0
# Time Step:128, Action: 0, Reward: 0.0
# Time Step:129, Action: 0, Reward: 0.0
# Time Step:130, Action: 0, Reward: 0.0
# Time Step:131, Action: 3, Reward: 0.0
# Time Step:132, Action: 2, Reward: 0.0
# Time Step:133, Action: 0, Reward: 0.0
# Time Step:134, Action: 0, Reward: 0.0
# Time Step:135, Action: 0, Reward: 0.0
# Time Step:136, Action: 2, Reward: 0.0
# Time Step:137, Action: 2, Reward: 0.0
# Time Step:138, Action: 0, Reward: 0.0
# Time Step:139, Action: 3, Reward: 0.0
# Time Step:140, Action: 3, Reward: 0.0
# Time Step:141, Action: 3, Reward: 0.0
# Time Step:142, Action: 3, Reward: 0.0
# Time Step:143, Action: 3, Reward: 0.0
# Time Step:144, Action: 0, Reward: 0.0
# Time Step:145, Action: 0, Reward: 0.0
# Time Step:146, Action: 0, Reward: 0.0
# Time Step:147, Action: 0, Reward: 0.0
# Time Step:148, Action: 3, Reward: 0.0
# Time Step:149, Action: 0, Reward: 0.0
# Time Step:150, Action: 3, Reward: 0.0
# Time Step:151, Action: 2, Reward: 0.0
# Time Step:152, Action: 2, Reward: 0.0
# Time Step:153, Action: 2, Reward: 0.0
# Time Step:154, Action: 2, Reward: 0.0
# Time Step:155, Action: 2, Reward: 0.0
# Time Step:156, Action: 0, Reward: 0.0
# Time Step:157, Action: 3, Reward: 0.0
# Time Step:158, Action: 3, Reward: 0.0
# Time Step:159, Action: 3, Reward: 0.0
# Time Step:160, Action: 3, Reward: 0.0
# Time Step:161, Action: 3, Reward: 0.0
# Time Step:162, Action: 2, Reward: 1.0
# Time Step:163, Action: 0, Reward: 0.0
# Time Step:164, Action: 0, Reward: 0.0
# Time Step:165, Action: 0, Reward: 0.0
# Time Step:166, Action: 0, Reward: 0.0
# Time Step:167, Action: 0, Reward: 0.0
# Time Step:168, Action: 0, Reward: 0.0
# Time Step:169, Action: 0, Reward: 0.0
# Time Step:170, Action: 0, Reward: 0.0
# Time Step:171, Action: 0, Reward: 0.0
# Time Step:172, Action: 0, Reward: 0.0
# Time Step:173, Action: 2, Reward: 0.0
# Time Step:174, Action: 2, Reward: 0.0
# Time Step:175, Action: 2, Reward: 0.0
# Time Step:176, Action: 0, Reward: 0.0
# Time Step:177, Action: 3, Reward: 0.0
# Time Step:178, Action: 3, Reward: 0.0
# Time Step:179, Action: 3, Reward: 0.0
# Time Step:180, Action: 2, Reward: 0.0
# Time Step:181, Action: 2, Reward: 0.0
# Time Step:182, Action: 3, Reward: 0.0
# Time Step:183, Action: 3, Reward: 0.0
# Time Step:184, Action: 0, Reward: 0.0
# Time Step:185, Action: 0, Reward: 0.0
# Time Step:186, Action: 2, Reward: 0.0
# Time Step:187, Action: 2, Reward: 0.0
# Time Step:188, Action: 0, Reward: 0.0
# Time Step:189, Action: 0, Reward: 0.0
# Time Step:190, Action: 2, Reward: 0.0
# Time Step:191, Action: 0, Reward: 0.0
# Time Step:192, Action: 0, Reward: 0.0
# Time Step:193, Action: 0, Reward: 0.0
# Time Step:194, Action: 0, Reward: 0.0
# Time Step:195, Action: 0, Reward: 0.0
# Time Step:196, Action: 0, Reward: 0.0
# Time Step:197, Action: 3, Reward: 0.0
# Time Step:198, Action: 3, Reward: 0.0
# Time Step:199, Action: 3, Reward: 0.0
# Time Step:200, Action: 0, Reward: 0.0
# Time Step:201, Action: 0, Reward: 0.0
# Time Step:202, Action: 3, Reward: 0.0
# Time Step:203, Action: 2, Reward: 0.0
# Time Step:204, Action: 0, Reward: 0.0
# Time Step:205, Action: 2, Reward: 0.0
# Time Step:206, Action: 3, Reward: 0.0
# Time Step:207, Action: 3, Reward: 0.0
# Time Step:208, Action: 2, Reward: 0.0
# Time Step:209, Action: 3, Reward: 0.0
# Time Step:210, Action: 2, Reward: 0.0
# Time Step:211, Action: 2, Reward: 0.0
# Time Step:212, Action: 2, Reward: 0.0
# Time Step:213, Action: 2, Reward: 0.0
# Time Step:214, Action: 2, Reward: 1.0
# Time Step:215, Action: 0, Reward: 0.0
# Time Step:216, Action: 0, Reward: 0.0
# Time Step:217, Action: 0, Reward: 0.0
# Time Step:218, Action: 0, Reward: 0.0
# Time Step:219, Action: 0, Reward: 0.0
# Time Step:220, Action: 0, Reward: 0.0
# Time Step:221, Action: 3, Reward: 0.0
# Time Step:222, Action: 0, Reward: 0.0
# Time Step:223, Action: 0, Reward: 0.0
# Time Step:224, Action: 0, Reward: 0.0
# Time Step:225, Action: 0, Reward: 0.0
# Time Step:226, Action: 3, Reward: 0.0
# Time Step:227, Action: 2, Reward: 0.0
# Time Step:228, Action: 1, Reward: 0.0
# Time Step:229, Action: 0, Reward: 0.0
# Time Step:230, Action: 3, Reward: 0.0
# Time Step:231, Action: 1, Reward: 0.0
# Time Step:232, Action: 3, Reward: 0.0
# Time Step:233, Action: 2, Reward: 0.0
# Time Step:234, Action: 3, Reward: 0.0
# Time Step:235, Action: 3, Reward: 0.0
# Time Step:236, Action: 3, Reward: 0.0
# Time Step:237, Action: 3, Reward: 0.0
# Time Step:238, Action: 3, Reward: 0.0
# Time Step:239, Action: 2, Reward: 0.0
# Time Step:240, Action: 2, Reward: 0.0
# Time Step:241, Action: 2, Reward: 0.0
# Time Step:242, Action: 2, Reward: 0.0
# Time Step:243, Action: 3, Reward: 0.0
# Time Step:244, Action: 3, Reward: 0.0
# Time Step:245, Action: 0, Reward: 0.0
# Time Step:246, Action: 0, Reward: 0.0
# Time Step:247, Action: 0, Reward: 0.0
# Time Step:248, Action: 0, Reward: 0.0
# Time Step:249, Action: 0, Reward: 0.0
# Time Step:250, Action: 2, Reward: 0.0
# Time Step:251, Action: 0, Reward: 0.0
# Time Step:252, Action: 0, Reward: 0.0
# Time Step:253, Action: 0, Reward: 0.0
# Time Step:254, Action: 0, Reward: 0.0
# Time Step:255, Action: 0, Reward: 0.0
# Time Step:256, Action: 2, Reward: 0.0
# Time Step:257, Action: 2, Reward: 0.0
# Time Step:258, Action: 2, Reward: 0.0
# Time Step:259, Action: 2, Reward: 0.0
# Time Step:260, Action: 2, Reward: 0.0
# Time Step:261, Action: 2, Reward: 0.0
# Time Step:262, Action: 3, Reward: 1.0
# Time Step:263, Action: 3, Reward: 0.0
# Time Step:264, Action: 2, Reward: 0.0
# Time Step:265, Action: 0, Reward: 0.0
# Time Step:266, Action: 3, Reward: 0.0
# Time Step:267, Action: 0, Reward: 0.0
# Time Step:268, Action: 0, Reward: 0.0
# Time Step:269, Action: 3, Reward: 0.0
# Time Step:270, Action: 0, Reward: 0.0
# Time Step:271, Action: 0, Reward: 0.0
# Time Step:272, Action: 0, Reward: 0.0
# Time Step:273, Action: 3, Reward: 0.0
# Time Step:274, Action: 3, Reward: 0.0
# Time Step:275, Action: 3, Reward: 0.0
# Time Step:276, Action: 3, Reward: 0.0
# Time Step:277, Action: 1, Reward: 0.0
# Time Step:278, Action: 3, Reward: 0.0
# Time Step:279, Action: 3, Reward: 0.0
# Time Step:280, Action: 1, Reward: 0.0
# Time Step:281, Action: 1, Reward: 0.0
# Time Step:282, Action: 0, Reward: 0.0
# Time Step:283, Action: 0, Reward: 0.0
# Time Step:284, Action: 0, Reward: 0.0
# Time Step:285, Action: 0, Reward: 0.0
# Time Step:286, Action: 0, Reward: 0.0
# Time Step:287, Action: 0, Reward: 0.0
# Time Step:288, Action: 0, Reward: 0.0
# Time Step:289, Action: 0, Reward: 0.0
# Time Step:290, Action: 0, Reward: 0.0
# Time Step:291, Action: 2, Reward: 0.0
# Time Step:292, Action: 0, Reward: 0.0
# Time Step:293, Action: 2, Reward: 0.0
# Time Step:294, Action: 2, Reward: 0.0
# Time Step:295, Action: 2, Reward: 0.0
# Time Step:296, Action: 2, Reward: 0.0
# Time Step:297, Action: 1, Reward: 0.0
# Time Step:298, Action: 0, Reward: 0.0
# Time Step:299, Action: 3, Reward: 0.0
# Time Step:300, Action: 3, Reward: 0.0
# Time Step:301, Action: 0, Reward: 0.0
# Time Step:302, Action: 0, Reward: 0.0
# Time Step:303, Action: 3, Reward: 0.0
# Time Step:304, Action: 0, Reward: 0.0
# Time Step:305, Action: 0, Reward: 0.0
# Time Step:306, Action: 0, Reward: 0.0
# Time Step:307, Action: 0, Reward: 0.0
# Time Step:308, Action: 0, Reward: 0.0
# Time Step:309, Action: 0, Reward: 0.0
# Time Step:310, Action: 0, Reward: 0.0
# Time Step:311, Action: 2, Reward: 0.0
# Time Step:312, Action: 0, Reward: 0.0
# Time Step:313, Action: 0, Reward: 0.0
# Time Step:314, Action: 0, Reward: 0.0
# Time Step:315, Action: 0, Reward: 0.0
# Time Step:316, Action: 3, Reward: 0.0
# Time Step:317, Action: 0, Reward: 0.0
# Time Step:318, Action: 0, Reward: 0.0
# Time Step:319, Action: 0, Reward: 0.0
# Time Step:320, Action: 0, Reward: 0.0
# Time Step:321, Action: 0, Reward: 0.0
# Time Step:322, Action: 1, Reward: 0.0
# Time Step:323, Action: 0, Reward: 0.0
# Time Step:324, Action: 0, Reward: 0.0
# Time Step:325, Action: 0, Reward: 0.0
# Time Step:326, Action: 0, Reward: 0.0
# Time Step:327, Action: 3, Reward: 0.0
# Time Step:328, Action: 0, Reward: 0.0
# Time Step:329, Action: 2, Reward: 0.0
# Time Step:330, Action: 0, Reward: 0.0
# Time Step:331, Action: 0, Reward: 0.0
# Time Step:332, Action: 0, Reward: 0.0
# Time Step:333, Action: 0, Reward: 0.0
# Time Step:334, Action: 1, Reward: 1.0
# Time Step:335, Action: 0, Reward: 0.0
# Time Step:336, Action: 0, Reward: 0.0
# Time Step:337, Action: 2, Reward: 0.0
# Time Step:338, Action: 0, Reward: 0.0
# Time Step:339, Action: 0, Reward: 0.0
# Time Step:340, Action: 0, Reward: 0.0
# Time Step:341, Action: 0, Reward: 0.0
# Time Step:342, Action: 0, Reward: 0.0
# Time Step:343, Action: 0, Reward: 0.0
# Time Step:344, Action: 0, Reward: 0.0
# Time Step:345, Action: 0, Reward: 0.0
# Time Step:346, Action: 0, Reward: 0.0
# Time Step:347, Action: 0, Reward: 0.0
# Time Step:348, Action: 0, Reward: 0.0
# Time Step:349, Action: 0, Reward: 0.0
# Time Step:350, Action: 0, Reward: 0.0
# Time Step:351, Action: 3, Reward: 0.0
# Time Step:352, Action: 3, Reward: 0.0
# Time Step:353, Action: 3, Reward: 0.0
# Time Step:354, Action: 0, Reward: 0.0
# Time Step:355, Action: 2, Reward: 0.0
# Time Step:356, Action: 2, Reward: 0.0
# Time Step:357, Action: 2, Reward: 0.0
# Time Step:358, Action: 2, Reward: 0.0
# Time Step:359, Action: 3, Reward: 0.0
# Time Step:360, Action: 3, Reward: 0.0
# Time Step:361, Action: 3, Reward: 0.0
# Time Step:362, Action: 2, Reward: 0.0
# Time Step:363, Action: 2, Reward: 0.0
# Time Step:364, Action: 3, Reward: 0.0
# Time Step:365, Action: 2, Reward: 0.0
# Time Step:366, Action: 2, Reward: 0.0
# Time Step:367, Action: 2, Reward: 0.0
# Time Step:368, Action: 2, Reward: 0.0
# Time Step:369, Action: 3, Reward: 0.0
# Time Step:370, Action: 0, Reward: 0.0
# Time Step:371, Action: 3, Reward: 0.0
# Time Step:372, Action: 0, Reward: 0.0
# Time Step:373, Action: 3, Reward: 0.0
# Time Step:374, Action: 3, Reward: 0.0
# Time Step:375, Action: 3, Reward: 0.0
# Time Step:376, Action: 2, Reward: 0.0
# Time Step:377, Action: 0, Reward: 0.0
# Time Step:378, Action: 3, Reward: 0.0
# Time Step:379, Action: 2, Reward: 0.0
# Time Step:380, Action: 1, Reward: 0.0
# Time Step:381, Action: 3, Reward: 0.0
# Time Step:382, Action: 0, Reward: 0.0
# Time Step:383, Action: 2, Reward: 0.0
# Time Step:384, Action: 3, Reward: 0.0
# Time Step:385, Action: 3, Reward: 0.0
# Time Step:386, Action: 2, Reward: 0.0
# Time Step:387, Action: 0, Reward: 0.0
# Time Step:388, Action: 0, Reward: 0.0
# Time Step:389, Action: 2, Reward: 0.0
# Time Step:390, Action: 2, Reward: 0.0
# Time Step:391, Action: 3, Reward: 0.0
# Time Step:392, Action: 2, Reward: 0.0
# Time Step:393, Action: 2, Reward: 0.0
# Time Step:394, Action: 2, Reward: 0.0
# Time Step:395, Action: 2, Reward: 0.0
# Time Step:396, Action: 3, Reward: 0.0
# Time Step:397, Action: 1, Reward: 0.0
# Time Step:398, Action: 3, Reward: 0.0
# Time Step:399, Action: 0, Reward: 0.0
# Time Step:400, Action: 0, Reward: 0.0
# Time Step:401, Action: 0, Reward: 0.0
# Time Step:402, Action: 0, Reward: 0.0
# Time Step:403, Action: 2, Reward: 0.0
# Time Step:404, Action: 2, Reward: 0.0
# Time Step:405, Action: 3, Reward: 0.0
# Time Step:406, Action: 2, Reward: 0.0
# Time Step:407, Action: 0, Reward: 0.0
# Time Step:408, Action: 0, Reward: 0.0
# Time Step:409, Action: 0, Reward: 0.0
# Time Step:410, Action: 0, Reward: 0.0
# Time Step:411, Action: 0, Reward: 0.0
# Time Step:412, Action: 0, Reward: 0.0
# Time Step:413, Action: 0, Reward: 0.0
# Time Step:414, Action: 0, Reward: 0.0
# Time Step:415, Action: 2, Reward: 0.0
# Time Step:416, Action: 2, Reward: 0.0
# Time Step:417, Action: 3, Reward: 0.0
# Time Step:418, Action: 3, Reward: 0.0
# Time Step:419, Action: 3, Reward: 0.0
# Time Step:420, Action: 3, Reward: 0.0
# Time Step:421, Action: 3, Reward: 0.0
# Time Step:422, Action: 3, Reward: 0.0
# Time Step:423, Action: 1, Reward: 0.0
# Time Step:424, Action: 2, Reward: 1.0
# Time Step:425, Action: 0, Reward: 0.0
# Time Step:426, Action: 0, Reward: 0.0
# Time Step:427, Action: 0, Reward: 0.0
# Time Step:428, Action: 0, Reward: 0.0
# Time Step:429, Action: 0, Reward: 0.0
# Time Step:430, Action: 0, Reward: 0.0
# Time Step:431, Action: 2, Reward: 0.0
# Time Step:432, Action: 2, Reward: 0.0
# Time Step:433, Action: 2, Reward: 0.0
# Time Step:434, Action: 2, Reward: 0.0
# Time Step:435, Action: 3, Reward: 0.0
# Time Step:436, Action: 3, Reward: 0.0
# Time Step:437, Action: 2, Reward: 0.0
# Time Step:438, Action: 3, Reward: 0.0
# Time Step:439, Action: 3, Reward: 0.0
# Time Step:440, Action: 3, Reward: 0.0
# Time Step:441, Action: 2, Reward: 0.0
# Time Step:442, Action: 3, Reward: 0.0
# Time Step:443, Action: 2, Reward: 0.0
# Time Step:444, Action: 2, Reward: 0.0
# Time Step:445, Action: 2, Reward: 0.0
# Time Step:446, Action: 3, Reward: 0.0
# Time Step:447, Action: 0, Reward: 0.0
# Time Step:448, Action: 3, Reward: 0.0
# Time Step:449, Action: 3, Reward: 0.0
# Time Step:450, Action: 0, Reward: 0.0
# Time Step:451, Action: 3, Reward: 0.0
# Time Step:452, Action: 0, Reward: 0.0
# Time Step:453, Action: 0, Reward: 0.0
# Time Step:454, Action: 3, Reward: 0.0
# Time Step:455, Action: 3, Reward: 0.0
# Time Step:456, Action: 0, Reward: 0.0
# Time Step:457, Action: 3, Reward: 0.0
# Time Step:458, Action: 2, Reward: 0.0
# Time Step:459, Action: 3, Reward: 0.0
# Time Step:460, Action: 3, Reward: 0.0
# Time Step:461, Action: 0, Reward: 0.0
# Time Step:462, Action: 2, Reward: 0.0
# Time Step:463, Action: 2, Reward: 0.0
# Time Step:464, Action: 0, Reward: 0.0
# Time Step:465, Action: 3, Reward: 0.0
# Time Step:466, Action: 3, Reward: 0.0
# Time Step:467, Action: 0, Reward: 0.0
# Time Step:468, Action: 0, Reward: 0.0
# Time Step:469, Action: 0, Reward: 0.0
# Time Step:470, Action: 2, Reward: 0.0
# Time Step:471, Action: 2, Reward: 0.0
# Time Step:472, Action: 2, Reward: 0.0
# Time Step:473, Action: 3, Reward: 0.0
# Time Step:474, Action: 2, Reward: 0.0
# Time Step:475, Action: 3, Reward: 0.0
# Time Step:476, Action: 0, Reward: 0.0
# Time Step:477, Action: 0, Reward: 0.0
# Time Step:478, Action: 3, Reward: 0.0
# Time Step:479, Action: 2, Reward: 0.0
# Time Step:480, Action: 3, Reward: 0.0
# Time Step:481, Action: 3, Reward: 1.0
# Time Step:482, Action: 0, Reward: 0.0
# Time Step:483, Action: 0, Reward: 0.0
# Time Step:484, Action: 0, Reward: 0.0
# Time Step:485, Action: 0, Reward: 0.0
# Time Step:486, Action: 0, Reward: 0.0
# Time Step:487, Action: 0, Reward: 0.0
# Time Step:488, Action: 0, Reward: 0.0
# Time Step:489, Action: 0, Reward: 0.0
# Time Step:490, Action: 0, Reward: 0.0
# Time Step:491, Action: 0, Reward: 0.0
# Time Step:492, Action: 3, Reward: 0.0
# Time Step:493, Action: 3, Reward: 0.0
# Time Step:494, Action: 2, Reward: 0.0
# Time Step:495, Action: 2, Reward: 0.0
# Time Step:496, Action: 0, Reward: 0.0
# Time Step:497, Action: 2, Reward: 0.0
# Time Step:498, Action: 2, Reward: 0.0
# Time Step:499, Action: 0, Reward: 0.0
# Time Step:500, Action: 0, Reward: 0.0
# Time Step:501, Action: 2, Reward: 0.0
# Time Step:502, Action: 2, Reward: 0.0
# Time Step:503, Action: 0, Reward: 0.0
# Time Step:504, Action: 0, Reward: 0.0
# Time Step:505, Action: 3, Reward: 0.0
# Time Step:506, Action: 0, Reward: 0.0
# Time Step:507, Action: 0, Reward: 0.0
# Time Step:508, Action: 3, Reward: 0.0
# Time Step:509, Action: 1, Reward: 0.0
# Time Step:510, Action: 0, Reward: 0.0
# Time Step:511, Action: 0, Reward: 0.0
# Time Step:512, Action: 2, Reward: 0.0
# Time Step:513, Action: 2, Reward: 0.0
# Time Step:514, Action: 1, Reward: 0.0
# Time Step:515, Action: 2, Reward: 0.0
# Time Step:516, Action: 3, Reward: 0.0
# Time Step:517, Action: 3, Reward: 0.0
# Time Step:518, Action: 0, Reward: 0.0
# Time Step:519, Action: 3, Reward: 0.0
# Time Step:520, Action: 0, Reward: 0.0
# Time Step:521, Action: 0, Reward: 0.0
# Time Step:522, Action: 0, Reward: 0.0
# Time Step:523, Action: 0, Reward: 0.0
# Time Step:524, Action: 0, Reward: 0.0
# Time Step:525, Action: 0, Reward: 0.0
# Time Step:526, Action: 0, Reward: 0.0
# Time Step:527, Action: 0, Reward: 0.0
# Time Step:528, Action: 0, Reward: 0.0
# Time Step:529, Action: 3, Reward: 0.0
# Time Step:530, Action: 0, Reward: 0.0
# Time Step:531, Action: 3, Reward: 0.0
# Time Step:532, Action: 0, Reward: 0.0
# Time Step:533, Action: 3, Reward: 0.0
# Time Step:534, Action: 3, Reward: 0.0
# Time Step:535, Action: 3, Reward: 0.0
# Time Step:536, Action: 2, Reward: 0.0
# Time Step:537, Action: 3, Reward: 0.0
# Time Step:538, Action: 1, Reward: 0.0
# Time Step:539, Action: 2, Reward: 0.0
# Time Step:540, Action: 0, Reward: 0.0
# Time Step:541, Action: 0, Reward: 1.0
# Time Step:542, Action: 0, Reward: 0.0
# Time Step:543, Action: 0, Reward: 0.0
# Time Step:544, Action: 0, Reward: 0.0
# Time Step:545, Action: 0, Reward: 0.0
# Time Step:546, Action: 0, Reward: 0.0
# Time Step:547, Action: 0, Reward: 0.0
# Time Step:548, Action: 0, Reward: 0.0
# Time Step:549, Action: 0, Reward: 0.0
# Time Step:550, Action: 0, Reward: 0.0
# Time Step:551, Action: 0, Reward: 0.0
# Time Step:552, Action: 0, Reward: 0.0
# Time Step:553, Action: 0, Reward: 0.0
# Time Step:554, Action: 2, Reward: 0.0
# Time Step:555, Action: 2, Reward: 0.0
# Time Step:556, Action: 2, Reward: 0.0
# Time Step:557, Action: 2, Reward: 0.0
# Time Step:558, Action: 0, Reward: 0.0
# Time Step:559, Action: 3, Reward: 0.0
# Time Step:560, Action: 0, Reward: 0.0
# Time Step:561, Action: 0, Reward: 0.0
# Time Step:562, Action: 3, Reward: 0.0
# Time Step:563, Action: 2, Reward: 0.0
# Time Step:564, Action: 2, Reward: 0.0
# Time Step:565, Action: 3, Reward: 0.0
# Time Step:566, Action: 3, Reward: 0.0
# Time Step:567, Action: 2, Reward: 0.0
# Time Step:568, Action: 2, Reward: 0.0
# Time Step:569, Action: 2, Reward: 0.0
# Time Step:570, Action: 3, Reward: 0.0
# Time Step:571, Action: 1, Reward: 0.0
# Time Step:572, Action: 0, Reward: 0.0
# Time Step:573, Action: 3, Reward: 0.0
# Time Step:574, Action: 3, Reward: 0.0
# Time Step:575, Action: 3, Reward: 0.0
# Time Step:576, Action: 0, Reward: 0.0
# Time Step:577, Action: 0, Reward: 0.0
# Time Step:578, Action: 0, Reward: 0.0
# Time Step:579, Action: 3, Reward: 0.0
# Time Step:580, Action: 0, Reward: 0.0
# Time Step:581, Action: 3, Reward: 0.0
# Time Step:582, Action: 3, Reward: 0.0
# Time Step:583, Action: 0, Reward: 0.0
# Time Step:584, Action: 3, Reward: 0.0
# Time Step:585, Action: 1, Reward: 0.0
# Time Step:586, Action: 3, Reward: 0.0
# Time Step:587, Action: 2, Reward: 1.0
# Time Step:588, Action: 3, Reward: 0.0
# Time Step:589, Action: 0, Reward: 0.0
# Time Step:590, Action: 2, Reward: 0.0
# Time Step:591, Action: 0, Reward: 0.0
# Time Step:592, Action: 0, Reward: 0.0
# Time Step:593, Action: 2, Reward: 0.0
# Time Step:594, Action: 2, Reward: 0.0
# Time Step:595, Action: 2, Reward: 0.0
# Time Step:596, Action: 3, Reward: 0.0
# Time Step:597, Action: 2, Reward: 0.0
# Time Step:598, Action: 2, Reward: 0.0
# Time Step:599, Action: 2, Reward: 0.0
# Time Step:600, Action: 3, Reward: 0.0
# Time Step:601, Action: 0, Reward: 0.0
# Time Step:602, Action: 3, Reward: 0.0
# Time Step:603, Action: 3, Reward: 0.0
# Time Step:604, Action: 1, Reward: 0.0
# Time Step:605, Action: 1, Reward: 0.0
# Time Step:606, Action: 1, Reward: 0.0
# Time Step:607, Action: 1, Reward: 0.0
# Time Step:608, Action: 1, Reward: 0.0
# Time Step:609, Action: 3, Reward: 0.0
# Time Step:610, Action: 0, Reward: 0.0
# Time Step:611, Action: 0, Reward: 0.0
# Time Step:612, Action: 3, Reward: 0.0
# Time Step:613, Action: 1, Reward: 0.0
# Time Step:614, Action: 2, Reward: 0.0
# Time Step:615, Action: 0, Reward: 0.0
# Time Step:616, Action: 3, Reward: 0.0
# Time Step:617, Action: 3, Reward: 0.0
# Time Step:618, Action: 3, Reward: 0.0
# Time Step:619, Action: 3, Reward: 0.0
# Time Step:620, Action: 3, Reward: 0.0
# Time Step:621, Action: 0, Reward: 0.0
# Time Step:622, Action: 3, Reward: 0.0
# Time Step:623, Action: 1, Reward: 0.0
# Time Step:624, Action: 3, Reward: 0.0
# Time Step:625, Action: 0, Reward: 0.0
# Time Step:626, Action: 3, Reward: 0.0
# Time Step:627, Action: 3, Reward: 0.0
# Time Step:628, Action: 3, Reward: 0.0
# Time Step:629, Action: 3, Reward: 0.0
# Time Step:630, Action: 2, Reward: 0.0
# Time Step:631, Action: 3, Reward: 0.0
# Time Step:632, Action: 3, Reward: 0.0
# Time Step:633, Action: 3, Reward: 0.0
# Time Step:634, Action: 3, Reward: 0.0
# Time Step:635, Action: 0, Reward: 0.0
# Time Step:636, Action: 0, Reward: 0.0
# Time Step:637, Action: 3, Reward: 0.0
# Time Step:638, Action: 0, Reward: 0.0
# Time Step:639, Action: 0, Reward: 0.0
# Time Step:640, Action: 1, Reward: 0.0
# Time Step:641, Action: 3, Reward: 0.0
# Time Step:642, Action: 0, Reward: 0.0
# Time Step:643, Action: 0, Reward: 0.0
# Time Step:644, Action: 0, Reward: 0.0
# Time Step:645, Action: 1, Reward: 0.0
# Time Step:646, Action: 1, Reward: 0.0
# Time Step:647, Action: 2, Reward: 0.0
# Time Step:648, Action: 0, Reward: 0.0
# Time Step:649, Action: 0, Reward: 0.0
# Time Step:650, Action: 1, Reward: 0.0
# Time Step:651, Action: 1, Reward: 1.0
# Time Step:652, Action: 0, Reward: 0.0
# Time Step:653, Action: 0, Reward: 0.0
# Time Step:654, Action: 0, Reward: 0.0
# Time Step:655, Action: 1, Reward: 0.0
# Time Step:656, Action: 0, Reward: 0.0
# Time Step:657, Action: 0, Reward: 0.0
# Time Step:658, Action: 0, Reward: 0.0
# Time Step:659, Action: 3, Reward: 0.0
# Time Step:660, Action: 1, Reward: 0.0
# Time Step:661, Action: 2, Reward: 0.0
# Time Step:662, Action: 2, Reward: 0.0
# Time Step:663, Action: 2, Reward: 0.0
# Time Step:664, Action: 2, Reward: 0.0
# Time Step:665, Action: 2, Reward: 0.0
# Time Step:666, Action: 1, Reward: 0.0
# Time Step:667, Action: 3, Reward: 0.0
# Time Step:668, Action: 3, Reward: 0.0
# Time Step:669, Action: 2, Reward: 0.0
# Time Step:670, Action: 3, Reward: 0.0
# Time Step:671, Action: 3, Reward: 0.0
# Time Step:672, Action: 3, Reward: 0.0
# Time Step:673, Action: 1, Reward: 0.0
# Time Step:674, Action: 0, Reward: 0.0
# Time Step:675, Action: 1, Reward: 0.0
# Time Step:676, Action: 1, Reward: 0.0
# Time Step:677, Action: 1, Reward: 0.0
# Time Step:678, Action: 1, Reward: 0.0
# Time Step:679, Action: 2, Reward: -20
# time step: 680, average reward: -9.0, episode: 0
# Time Step:680, Action: 1, Reward: 0.0
# Time Step:681, Action: 2, Reward: 0.0
# Time Step:682, Action: 0, Reward: 0.0
# Time Step:683, Action: 3, Reward: 0.0
# Time Step:684, Action: 3, Reward: 0.0
# Time Step:685, Action: 3, Reward: 0.0
# Time Step:686, Action: 3, Reward: 0.0
# Time Step:687, Action: 0, Reward: 0.0
# Time Step:688, Action: 0, Reward: 0.0
# Time Step:689, Action: 0, Reward: 0.0
# Time Step:690, Action: 2, Reward: 0.0
# Time Step:691, Action: 3, Reward: 0.0
# Time Step:692, Action: 3, Reward: 0.0
# Time Step:693, Action: 3, Reward: 0.0
# Time Step:694, Action: 2, Reward: 0.0
# Time Step:695, Action: 3, Reward: 0.0
# Time Step:696, Action: 3, Reward: 0.0
# Time Step:697, Action: 3, Reward: 0.0
# Time Step:698, Action: 0, Reward: 0.0
# Time Step:699, Action: 3, Reward: 0.0
# Time Step:700, Action: 3, Reward: 0.0
# Time Step:701, Action: 3, Reward: 0.0
# Time Step:702, Action: 3, Reward: 0.0
# Time Step:703, Action: 3, Reward: 0.0
# Time Step:704, Action: 3, Reward: 0.0
# Time Step:705, Action: 3, Reward: 0.0
# Time Step:706, Action: 3, Reward: 0.0
# Time Step:707, Action: 3, Reward: 0.0
# Time Step:708, Action: 3, Reward: 0.0
# Time Step:709, Action: 0, Reward: 0.0
# Time Step:710, Action: 0, Reward: 0.0
# Time Step:711, Action: 0, Reward: 0.0
# Time Step:712, Action: 0, Reward: 0.0
# Time Step:713, Action: 0, Reward: 0.0
# Time Step:714, Action: 1, Reward: 0.0
# Time Step:715, Action: 3, Reward: 0.0
# Time Step:716, Action: 0, Reward: 0.0
# Time Step:717, Action: 0, Reward: 0.0
# Time Step:718, Action: 0, Reward: 0.0
# Time Step:719, Action: 2, Reward: 0.0
# Time Step:720, Action: 2, Reward: 0.0
# Time Step:721, Action: 0, Reward: 0.0
# Time Step:722, Action: 0, Reward: 0.0
# Time Step:723, Action: 0, Reward: 1.0
# Time Step:724, Action: 0, Reward: 0.0
# Time Step:725, Action: 0, Reward: 0.0
# Time Step:726, Action: 0, Reward: 0.0
# Time Step:727, Action: 0, Reward: 0.0
# Time Step:728, Action: 0, Reward: 0.0
# Time Step:729, Action: 0, Reward: 0.0
# Time Step:730, Action: 0, Reward: 0.0
# Time Step:731, Action: 0, Reward: 0.0
# Time Step:732, Action: 0, Reward: 0.0
# Time Step:733, Action: 0, Reward: 0.0
# Time Step:734, Action: 2, Reward: 0.0
# Time Step:735, Action: 0, Reward: 0.0
# Time Step:736, Action: 2, Reward: 0.0
# Time Step:737, Action: 2, Reward: 0.0
# Time Step:738, Action: 2, Reward: 0.0
# Time Step:739, Action: 0, Reward: 0.0
# Time Step:740, Action: 2, Reward: 0.0
# Time Step:741, Action: 2, Reward: 0.0
# Time Step:742, Action: 2, Reward: 0.0
# Time Step:743, Action: 3, Reward: 0.0
# Time Step:744, Action: 3, Reward: 0.0
# Time Step:745, Action: 3, Reward: 0.0
# Time Step:746, Action: 0, Reward: 0.0
# Time Step:747, Action: 0, Reward: 0.0
# Time Step:748, Action: 3, Reward: 0.0
# Time Step:749, Action: 0, Reward: 0.0
# Time Step:750, Action: 2, Reward: 0.0
# Time Step:751, Action: 2, Reward: 0.0
# Time Step:752, Action: 2, Reward: 0.0
# Time Step:753, Action: 0, Reward: 0.0
# Time Step:754, Action: 2, Reward: 0.0
# Time Step:755, Action: 2, Reward: 0.0
# Time Step:756, Action: 0, Reward: 0.0
# Time Step:757, Action: 1, Reward: 0.0
# Time Step:758, Action: 0, Reward: 0.0
# Time Step:759, Action: 1, Reward: 0.0
# Time Step:760, Action: 2, Reward: 0.0
# Time Step:761, Action: 2, Reward: 0.0
# Time Step:762, Action: 3, Reward: 0.0
# Time Step:763, Action: 3, Reward: 0.0
# Time Step:764, Action: 0, Reward: 1.0
# Time Step:765, Action: 1, Reward: 0.0
# Time Step:766, Action: 0, Reward: 0.0
# Time Step:767, Action: 0, Reward: 0.0
# Time Step:768, Action: 0, Reward: 0.0
# Time Step:769, Action: 3, Reward: 0.0
# Time Step:770, Action: 3, Reward: 0.0
# Time Step:771, Action: 0, Reward: 0.0
# Time Step:772, Action: 0, Reward: 0.0
# Time Step:773, Action: 3, Reward: 0.0
# Time Step:774, Action: 3, Reward: 0.0
# Time Step:775, Action: 3, Reward: 0.0
# Time Step:776, Action: 0, Reward: 0.0
# Time Step:777, Action: 3, Reward: 0.0
# Time Step:778, Action: 3, Reward: 0.0
# Time Step:779, Action: 0, Reward: 0.0
# Time Step:780, Action: 3, Reward: 0.0
# Time Step:781, Action: 3, Reward: 0.0
# Time Step:782, Action: 3, Reward: 0.0
# Time Step:783, Action: 1, Reward: 0.0
# Time Step:784, Action: 3, Reward: 0.0
# Time Step:785, Action: 3, Reward: 0.0
# Time Step:786, Action: 2, Reward: 0.0
# Time Step:787, Action: 2, Reward: 0.0
# Time Step:788, Action: 3, Reward: 0.0
# Time Step:789, Action: 3, Reward: 0.0
# Time Step:790, Action: 0, Reward: 0.0
# Time Step:791, Action: 0, Reward: 0.0
# Time Step:792, Action: 0, Reward: 0.0
# Time Step:793, Action: 2, Reward: 0.0
# Time Step:794, Action: 0, Reward: 0.0
# Time Step:795, Action: 2, Reward: 0.0
# Time Step:796, Action: 0, Reward: 0.0
# Time Step:797, Action: 0, Reward: 0.0
# Time Step:798, Action: 0, Reward: 0.0
# Time Step:799, Action: 0, Reward: 0.0
# Time Step:800, Action: 2, Reward: 0.0
# Time Step:801, Action: 3, Reward: 0.0
# Time Step:802, Action: 0, Reward: 0.0
# Time Step:803, Action: 0, Reward: 0.0
# Time Step:804, Action: 2, Reward: 0.0
# Time Step:805, Action: 0, Reward: 0.0
# Time Step:806, Action: 0, Reward: 0.0
# Time Step:807, Action: 2, Reward: 0.0
# Time Step:808, Action: 0, Reward: 0.0
# Time Step:809, Action: 3, Reward: 0.0
# Time Step:810, Action: 3, Reward: 0.0
# Time Step:811, Action: 1, Reward: 0.0
# Time Step:812, Action: 3, Reward: 0.0
# Time Step:813, Action: 3, Reward: 0.0
# Time Step:814, Action: 3, Reward: 0.0
# Time Step:815, Action: 3, Reward: 0.0
# Time Step:816, Action: 3, Reward: 0.0
# Time Step:817, Action: 3, Reward: 0.0
# Time Step:818, Action: 3, Reward: 1.0
# Time Step:819, Action: 0, Reward: 0.0
# Time Step:820, Action: 0, Reward: 0.0
# Time Step:821, Action: 0, Reward: 0.0
# Time Step:822, Action: 0, Reward: 0.0
# Time Step:823, Action: 0, Reward: 0.0
# Time Step:824, Action: 0, Reward: 0.0
# Time Step:825, Action: 2, Reward: 0.0
# Time Step:826, Action: 0, Reward: 0.0
# Time Step:827, Action: 0, Reward: 0.0
# Time Step:828, Action: 0, Reward: 0.0
# Time Step:829, Action: 0, Reward: 0.0
# Time Step:830, Action: 0, Reward: 0.0
# Time Step:831, Action: 0, Reward: 0.0
# Time Step:832, Action: 0, Reward: 0.0
# Time Step:833, Action: 3, Reward: 0.0
# Time Step:834, Action: 2, Reward: 0.0
# Time Step:835, Action: 0, Reward: 0.0
# Time Step:836, Action: 2, Reward: 0.0
# Time Step:837, Action: 2, Reward: 0.0
# Time Step:838, Action: 0, Reward: 0.0
# Time Step:839, Action: 0, Reward: 0.0
# Time Step:840, Action: 3, Reward: 0.0
# Time Step:841, Action: 1, Reward: 0.0
# Time Step:842, Action: 3, Reward: 0.0
# Time Step:843, Action: 3, Reward: 0.0
# Time Step:844, Action: 3, Reward: 0.0
# Time Step:845, Action: 1, Reward: 0.0
# Time Step:846, Action: 3, Reward: 0.0
# Time Step:847, Action: 3, Reward: 0.0
# Time Step:848, Action: 3, Reward: 0.0
# Time Step:849, Action: 3, Reward: 0.0
# Time Step:850, Action: 1, Reward: 0.0
# Time Step:851, Action: 3, Reward: 0.0
# Time Step:852, Action: 3, Reward: 0.0
# Time Step:853, Action: 3, Reward: 0.0
# Time Step:854, Action: 0, Reward: 0.0
# Time Step:855, Action: 0, Reward: 0.0
# Time Step:856, Action: 0, Reward: 0.0
# Time Step:857, Action: 0, Reward: 0.0
# Time Step:858, Action: 0, Reward: 0.0
# Time Step:859, Action: 0, Reward: 0.0
# Time Step:860, Action: 0, Reward: 0.0
# Time Step:861, Action: 2, Reward: 0.0
# Time Step:862, Action: 3, Reward: 0.0
# Time Step:863, Action: 2, Reward: 0.0
# Time Step:864, Action: 2, Reward: 0.0
# Time Step:865, Action: 3, Reward: 0.0
# Time Step:866, Action: 2, Reward: 1.0
# Time Step:867, Action: 0, Reward: 0.0
# Time Step:868, Action: 0, Reward: 0.0
# Time Step:869, Action: 2, Reward: 0.0
# Time Step:870, Action: 0, Reward: 0.0
# Time Step:871, Action: 0, Reward: 0.0
# Time Step:872, Action: 3, Reward: 0.0
# Time Step:873, Action: 0, Reward: 0.0
# Time Step:874, Action: 0, Reward: 0.0
# Time Step:875, Action: 0, Reward: 0.0
# Time Step:876, Action: 0, Reward: 0.0
# Time Step:877, Action: 0, Reward: 0.0
# Time Step:878, Action: 2, Reward: 0.0
# Time Step:879, Action: 0, Reward: 0.0
# Time Step:880, Action: 1, Reward: 0.0
# Time Step:881, Action: 1, Reward: 0.0
# Time Step:882, Action: 1, Reward: 0.0
# Time Step:883, Action: 3, Reward: 0.0
# Time Step:884, Action: 3, Reward: 0.0
# Time Step:885, Action: 0, Reward: 0.0
# Time Step:886, Action: 0, Reward: 0.0
# Time Step:887, Action: 0, Reward: 0.0
# Time Step:888, Action: 3, Reward: 0.0
# Time Step:889, Action: 0, Reward: 0.0
# Time Step:890, Action: 0, Reward: 0.0
# Time Step:891, Action: 0, Reward: 0.0
# Time Step:892, Action: 0, Reward: 0.0
# Time Step:893, Action: 0, Reward: 0.0
# Time Step:894, Action: 3, Reward: 0.0
# Time Step:895, Action: 3, Reward: 0.0
# Time Step:896, Action: 2, Reward: 0.0
# Time Step:897, Action: 3, Reward: 0.0
# Time Step:898, Action: 2, Reward: 0.0
# Time Step:899, Action: 1, Reward: 0.0
# Time Step:900, Action: 3, Reward: 1.0
# Time Step:901, Action: 0, Reward: 0.0
# Time Step:902, Action: 0, Reward: 0.0
# Time Step:903, Action: 0, Reward: 0.0
# Time Step:904, Action: 0, Reward: 0.0
# Time Step:905, Action: 0, Reward: 0.0
# Time Step:906, Action: 0, Reward: 0.0
# Time Step:907, Action: 0, Reward: 0.0
# Time Step:908, Action: 0, Reward: 0.0
# Time Step:909, Action: 0, Reward: 0.0
# Time Step:910, Action: 0, Reward: 0.0
# Time Step:911, Action: 0, Reward: 0.0
# Time Step:912, Action: 1, Reward: 0.0
# Time Step:913, Action: 2, Reward: 0.0
# Time Step:914, Action: 1, Reward: 0.0
# Time Step:915, Action: 2, Reward: 0.0
# Time Step:916, Action: 3, Reward: 0.0
# Time Step:917, Action: 3, Reward: 0.0
# Time Step:918, Action: 3, Reward: 0.0
# Time Step:919, Action: 3, Reward: 0.0
# Time Step:920, Action: 1, Reward: 0.0
# Time Step:921, Action: 1, Reward: 0.0
# Time Step:922, Action: 1, Reward: 0.0
# Time Step:923, Action: 0, Reward: 0.0
# Time Step:924, Action: 0, Reward: 0.0
# Time Step:925, Action: 2, Reward: 0.0
# Time Step:926, Action: 2, Reward: 0.0
# Time Step:927, Action: 2, Reward: 0.0
# Time Step:928, Action: 2, Reward: 0.0
# Time Step:929, Action: 0, Reward: 0.0
# Time Step:930, Action: 0, Reward: 0.0
# Time Step:931, Action: 0, Reward: 0.0
# Time Step:932, Action: 3, Reward: 0.0
# Time Step:933, Action: 0, Reward: 0.0
# Time Step:934, Action: 3, Reward: 0.0
# Time Step:935, Action: 2, Reward: 0.0
# Time Step:936, Action: 2, Reward: 0.0
# Time Step:937, Action: 1, Reward: 0.0
# Time Step:938, Action: 0, Reward: 0.0
# Time Step:939, Action: 1, Reward: 0.0
# Time Step:940, Action: 0, Reward: 0.0
# Time Step:941, Action: 3, Reward: 0.0
# Time Step:942, Action: 2, Reward: 0.0
# Time Step:943, Action: 0, Reward: 0.0
# Time Step:944, Action: 0, Reward: 0.0
# Time Step:945, Action: 3, Reward: 0.0
# Time Step:946, Action: 0, Reward: 0.0
# Time Step:947, Action: 3, Reward: 0.0
# Time Step:948, Action: 0, Reward: 0.0
# Time Step:949, Action: 0, Reward: 0.0
# Time Step:950, Action: 0, Reward: 0.0
# Time Step:951, Action: 3, Reward: 0.0
# Time Step:952, Action: 3, Reward: 0.0
# Time Step:953, Action: 3, Reward: 0.0
# Time Step:954, Action: 3, Reward: 0.0
# Time Step:955, Action: 3, Reward: 0.0
# Time Step:956, Action: 0, Reward: 0.0
# Time Step:957, Action: 0, Reward: 0.0
# Time Step:958, Action: 2, Reward: 0.0
# Time Step:959, Action: 0, Reward: 0.0
# Time Step:960, Action: 0, Reward: 0.0
# Time Step:961, Action: 0, Reward: 0.0
# Time Step:962, Action: 3, Reward: 0.0
# Time Step:963, Action: 2, Reward: 0.0
# Time Step:964, Action: 0, Reward: 0.0
# Time Step:965, Action: 3, Reward: 0.0
# Time Step:966, Action: 0, Reward: 0.0
# Time Step:967, Action: 1, Reward: 0.0
# Time Step:968, Action: 1, Reward: 0.0
# Time Step:969, Action: 1, Reward: 0.0
# Time Step:970, Action: 1, Reward: 0.0
# Time Step:971, Action: 0, Reward: 0.0
# Time Step:972, Action: 1, Reward: 1.0
# Time Step:973, Action: 0, Reward: 0.0
# Time Step:974, Action: 0, Reward: 0.0
# Time Step:975, Action: 0, Reward: 0.0
# Time Step:976, Action: 0, Reward: 0.0
# Time Step:977, Action: 0, Reward: 0.0
# Time Step:978, Action: 0, Reward: 0.0
# Time Step:979, Action: 0, Reward: 0.0
# Time Step:980, Action: 0, Reward: 0.0
# Time Step:981, Action: 0, Reward: 0.0
# Time Step:982, Action: 0, Reward: 0.0
# Time Step:983, Action: 0, Reward: 0.0
# Time Step:984, Action: 3, Reward: 0.0
# Time Step:985, Action: 0, Reward: 0.0
# Time Step:986, Action: 0, Reward: 0.0
# Time Step:987, Action: 0, Reward: 0.0
# Time Step:988, Action: 0, Reward: 0.0
# Time Step:989, Action: 2, Reward: 0.0
# Time Step:990, Action: 2, Reward: 0.0
# Time Step:991, Action: 2, Reward: 0.0
# Time Step:992, Action: 2, Reward: 0.0
# Time Step:993, Action: 3, Reward: 0.0
# Time Step:994, Action: 3, Reward: 0.0
# Time Step:995, Action: 1, Reward: 0.0
# Time Step:996, Action: 3, Reward: 0.0
# Time Step:997, Action: 3, Reward: 0.0
# Time Step:998, Action: 2, Reward: 0.0
# Time Step:999, Action: 2, Reward: 0.0
# Time Step:1000, Action: 2, Reward: 0.0
# Time Step:1001, Action: 0, Reward: 0.0
# Time Step:1002, Action: 3, Reward: 0.0
# Time Step:1003, Action: 1, Reward: 0.0
# Time Step:1004, Action: 0, Reward: 0.0
# Time Step:1005, Action: 3, Reward: 0.0
# Time Step:1006, Action: 0, Reward: 0.0
# Time Step:1007, Action: 3, Reward: 0.0
# Time Step:1008, Action: 0, Reward: 0.0
# Time Step:1009, Action: 0, Reward: 0.0
# Time Step:1010, Action: 0, Reward: 0.0
# Time Step:1011, Action: 0, Reward: 0.0
# Time Step:1012, Action: 0, Reward: 0.0
# Time Step:1013, Action: 0, Reward: 0.0
# Time Step:1014, Action: 0, Reward: 0.0
# Time Step:1015, Action: 3, Reward: 0.0
# Time Step:1016, Action: 3, Reward: 0.0
# Time Step:1017, Action: 3, Reward: 0.0
# Time Step:1018, Action: 3, Reward: 0.0
# Time Step:1019, Action: 3, Reward: 0.0
# Time Step:1020, Action: 3, Reward: 0.0
# Time Step:1021, Action: 0, Reward: 0.0
# Time Step:1022, Action: 3, Reward: 0.0
# Time Step:1023, Action: 2, Reward: 0.0
# Time Step:1024, Action: 2, Reward: 0.0
# Time Step:1025, Action: 2, Reward: 0.0
# Time Step:1026, Action: 2, Reward: 0.0
# Time Step:1027, Action: 2, Reward: 0.0
# Time Step:1028, Action: 3, Reward: 0.0
# Time Step:1029, Action: 1, Reward: 0.0
# Time Step:1030, Action: 0, Reward: 0.0
# Time Step:1031, Action: 1, Reward: 0.0
# Time Step:1032, Action: 3, Reward: 1.0
# Time Step:1033, Action: 0, Reward: 0.0
# Time Step:1034, Action: 0, Reward: 0.0
# Time Step:1035, Action: 0, Reward: 0.0
# Time Step:1036, Action: 0, Reward: 0.0
# Time Step:1037, Action: 0, Reward: 0.0
# Time Step:1038, Action: 0, Reward: 0.0
# Time Step:1039, Action: 0, Reward: 0.0
# Time Step:1040, Action: 0, Reward: 0.0
# Time Step:1041, Action: 1, Reward: 0.0
# Time Step:1042, Action: 1, Reward: 0.0
# Time Step:1043, Action: 0, Reward: 0.0
# Time Step:1044, Action: 0, Reward: 0.0
# Time Step:1045, Action: 0, Reward: 0.0
# Time Step:1046, Action: 0, Reward: 0.0
# Time Step:1047, Action: 0, Reward: 0.0
# Time Step:1048, Action: 2, Reward: 0.0
# Time Step:1049, Action: 0, Reward: 0.0
# Time Step:1050, Action: 3, Reward: 0.0
# Time Step:1051, Action: 3, Reward: 0.0
# Time Step:1052, Action: 3, Reward: 0.0
# Time Step:1053, Action: 1, Reward: 0.0
# Time Step:1054, Action: 2, Reward: 0.0
# Time Step:1055, Action: 2, Reward: 0.0
# Time Step:1056, Action: 3, Reward: 0.0
# Time Step:1057, Action: 2, Reward: 0.0
# Time Step:1058, Action: 3, Reward: 0.0
# Time Step:1059, Action: 2, Reward: 0.0
# Time Step:1060, Action: 2, Reward: 0.0
# Time Step:1061, Action: 1, Reward: 0.0
# Time Step:1062, Action: 3, Reward: 0.0
# Time Step:1063, Action: 1, Reward: 0.0
# Time Step:1064, Action: 3, Reward: 0.0
# Time Step:1065, Action: 3, Reward: 0.0
# Time Step:1066, Action: 3, Reward: 0.0
# Time Step:1067, Action: 3, Reward: 0.0
# Time Step:1068, Action: 2, Reward: 0.0
# Time Step:1069, Action: 3, Reward: 0.0
# Time Step:1070, Action: 3, Reward: 0.0
# Time Step:1071, Action: 0, Reward: 0.0
# Time Step:1072, Action: 0, Reward: 0.0
# Time Step:1073, Action: 3, Reward: 0.0
# Time Step:1074, Action: 2, Reward: 0.0
# Time Step:1075, Action: 3, Reward: 0.0
# Time Step:1076, Action: 0, Reward: 0.0
# Time Step:1077, Action: 3, Reward: 0.0
# Time Step:1078, Action: 3, Reward: 0.0
# Time Step:1079, Action: 2, Reward: 0.0
# Time Step:1080, Action: 2, Reward: 0.0
# Time Step:1081, Action: 2, Reward: 0.0
# Time Step:1082, Action: 3, Reward: 0.0
# Time Step:1083, Action: 3, Reward: 0.0
# Time Step:1084, Action: 2, Reward: 0.0
# Time Step:1085, Action: 2, Reward: 0.0
# Time Step:1086, Action: 2, Reward: 0.0
# Time Step:1087, Action: 2, Reward: 0.0
# Time Step:1088, Action: 2, Reward: 0.0
# Time Step:1089, Action: 2, Reward: 0.0
# Time Step:1090, Action: 0, Reward: 0.0
# Time Step:1091, Action: 0, Reward: 0.0
# Time Step:1092, Action: 0, Reward: 0.0
# Time Step:1093, Action: 1, Reward: 0.0
# Time Step:1094, Action: 0, Reward: 0.0
# Time Step:1095, Action: 1, Reward: 0.0
# Time Step:1096, Action: 3, Reward: 1.0
# Time Step:1097, Action: 1, Reward: 0.0
# Time Step:1098, Action: 0, Reward: 0.0
# Time Step:1099, Action: 0, Reward: 0.0
# Time Step:1100, Action: 3, Reward: 0.0
# Time Step:1101, Action: 3, Reward: 0.0
# Time Step:1102, Action: 3, Reward: 0.0
# Time Step:1103, Action: 2, Reward: 0.0
# Time Step:1104, Action: 3, Reward: 0.0
# Time Step:1105, Action: 3, Reward: 0.0
# Time Step:1106, Action: 3, Reward: 0.0
# Time Step:1107, Action: 3, Reward: 0.0
# Time Step:1108, Action: 2, Reward: 0.0
# Time Step:1109, Action: 1, Reward: 0.0
# Time Step:1110, Action: 2, Reward: 0.0
# Time Step:1111, Action: 0, Reward: 0.0
# Time Step:1112, Action: 0, Reward: 0.0
# Time Step:1113, Action: 2, Reward: 0.0
# Time Step:1114, Action: 2, Reward: 0.0
# Time Step:1115, Action: 2, Reward: 0.0
# Time Step:1116, Action: 2, Reward: 0.0
# Time Step:1117, Action: 1, Reward: 0.0
# Time Step:1118, Action: 3, Reward: 0.0
# Time Step:1119, Action: 0, Reward: 0.0
# Time Step:1120, Action: 3, Reward: 0.0
# Time Step:1121, Action: 1, Reward: 0.0
# Time Step:1122, Action: 1, Reward: 0.0
# Time Step:1123, Action: 3, Reward: 0.0
# Time Step:1124, Action: 1, Reward: 0.0
# Time Step:1125, Action: 2, Reward: 0.0
# Time Step:1126, Action: 0, Reward: 0.0
# Time Step:1127, Action: 2, Reward: 0.0
# Time Step:1128, Action: 2, Reward: 0.0
# Time Step:1129, Action: 0, Reward: 0.0
# Time Step:1130, Action: 3, Reward: 0.0
# Time Step:1131, Action: 3, Reward: 0.0
# Time Step:1132, Action: 0, Reward: 0.0
# Time Step:1133, Action: 3, Reward: 0.0
# Time Step:1134, Action: 3, Reward: 0.0
# Time Step:1135, Action: 3, Reward: 0.0
# Time Step:1136, Action: 3, Reward: 0.0
# Time Step:1137, Action: 2, Reward: 0.0
# Time Step:1138, Action: 3, Reward: 0.0
# Time Step:1139, Action: 0, Reward: 0.0
# Time Step:1140, Action: 3, Reward: 0.0
# Time Step:1141, Action: 3, Reward: 0.0
# Time Step:1142, Action: 2, Reward: 0.0
# Time Step:1143, Action: 3, Reward: 0.0
# Time Step:1144, Action: 3, Reward: 0.0
# Time Step:1145, Action: 2, Reward: 1.0
# Time Step:1146, Action: 0, Reward: 0.0
# Time Step:1147, Action: 0, Reward: 0.0
# Time Step:1148, Action: 0, Reward: 0.0
# Time Step:1149, Action: 3, Reward: 0.0
# Time Step:1150, Action: 0, Reward: 0.0
# Time Step:1151, Action: 0, Reward: 0.0
# Time Step:1152, Action: 0, Reward: 0.0
# Time Step:1153, Action: 2, Reward: 0.0
# Time Step:1154, Action: 2, Reward: 0.0
# Time Step:1155, Action: 2, Reward: 0.0
# Time Step:1156, Action: 2, Reward: 0.0
# Time Step:1157, Action: 1, Reward: 0.0
# Time Step:1158, Action: 3, Reward: 0.0
# Time Step:1159, Action: 1, Reward: 0.0
# Time Step:1160, Action: 2, Reward: 0.0
# Time Step:1161, Action: 2, Reward: 0.0
# Time Step:1162, Action: 3, Reward: 0.0
# Time Step:1163, Action: 0, Reward: 0.0
# Time Step:1164, Action: 3, Reward: 0.0
# Time Step:1165, Action: 0, Reward: 0.0
# Time Step:1166, Action: 0, Reward: 0.0
# Time Step:1167, Action: 0, Reward: 0.0
# Time Step:1168, Action: 3, Reward: 0.0
# Time Step:1169, Action: 0, Reward: 0.0
# Time Step:1170, Action: 2, Reward: 0.0
# Time Step:1171, Action: 2, Reward: 0.0
# Time Step:1172, Action: 2, Reward: 0.0
# Time Step:1173, Action: 2, Reward: 0.0
# Time Step:1174, Action: 2, Reward: 0.0
# Time Step:1175, Action: 2, Reward: 0.0
# Time Step:1176, Action: 2, Reward: 0.0
# Time Step:1177, Action: 3, Reward: 1.0
# Time Step:1178, Action: 3, Reward: 0.0
# Time Step:1179, Action: 3, Reward: 0.0
# Time Step:1180, Action: 3, Reward: 0.0
# Time Step:1181, Action: 3, Reward: 0.0
# Time Step:1182, Action: 3, Reward: 0.0
# Time Step:1183, Action: 2, Reward: 0.0
# Time Step:1184, Action: 2, Reward: 0.0
# Time Step:1185, Action: 1, Reward: 0.0
# Time Step:1186, Action: 1, Reward: 0.0
# Time Step:1187, Action: 1, Reward: 0.0
# Time Step:1188, Action: 3, Reward: 0.0
# Time Step:1189, Action: 3, Reward: 0.0
# Time Step:1190, Action: 3, Reward: 0.0
# Time Step:1191, Action: 3, Reward: 0.0
# Time Step:1192, Action: 3, Reward: 0.0
# Time Step:1193, Action: 3, Reward: 0.0
# Time Step:1194, Action: 3, Reward: 0.0
# Time Step:1195, Action: 0, Reward: 0.0
# Time Step:1196, Action: 0, Reward: 0.0
# Time Step:1197, Action: 0, Reward: 0.0
# Time Step:1198, Action: 2, Reward: 0.0
# Time Step:1199, Action: 0, Reward: 0.0
# Time Step:1200, Action: 0, Reward: 0.0
# Time Step:1201, Action: 0, Reward: 0.0
# Time Step:1202, Action: 2, Reward: 0.0
# Time Step:1203, Action: 2, Reward: 0.0
# Time Step:1204, Action: 3, Reward: 0.0
# Time Step:1205, Action: 3, Reward: 0.0
# Time Step:1206, Action: 1, Reward: 0.0
# Time Step:1207, Action: 1, Reward: 1.0
# Time Step:1208, Action: 3, Reward: 0.0
# Time Step:1209, Action: 0, Reward: 0.0
# Time Step:1210, Action: 0, Reward: 0.0
# Time Step:1211, Action: 0, Reward: 0.0
# Time Step:1212, Action: 0, Reward: 0.0
# Time Step:1213, Action: 0, Reward: 0.0
# Time Step:1214, Action: 1, Reward: 0.0
# Time Step:1215, Action: 1, Reward: 0.0
# Time Step:1216, Action: 1, Reward: 0.0
# Time Step:1217, Action: 3, Reward: 0.0
# Time Step:1218, Action: 1, Reward: 0.0
# Time Step:1219, Action: 1, Reward: 0.0
# Time Step:1220, Action: 1, Reward: 0.0
# Time Step:1221, Action: 2, Reward: 0.0
# Time Step:1222, Action: 2, Reward: 0.0
# Time Step:1223, Action: 1, Reward: 0.0
# Time Step:1224, Action: 3, Reward: 0.0
# Time Step:1225, Action: 1, Reward: 0.0
# Time Step:1226, Action: 1, Reward: 0.0
# Time Step:1227, Action: 1, Reward: 0.0
# Time Step:1228, Action: 1, Reward: 0.0
# Time Step:1229, Action: 1, Reward: 0.0
# Time Step:1230, Action: 1, Reward: 0.0
# Time Step:1231, Action: 2, Reward: 0.0
# Time Step:1232, Action: 2, Reward: 0.0
# Time Step:1233, Action: 2, Reward: 0.0
# Time Step:1234, Action: 0, Reward: 0.0
# Time Step:1235, Action: 1, Reward: 0.0
# Time Step:1236, Action: 1, Reward: 0.0
# Time Step:1237, Action: 2, Reward: 0.0
# Time Step:1238, Action: 3, Reward: 0.0
# Time Step:1239, Action: 1, Reward: 0.0
# Time Step:1240, Action: 2, Reward: 0.0
# Time Step:1241, Action: 3, Reward: 0.0
# Time Step:1242, Action: 3, Reward: 0.0
# Time Step:1243, Action: 2, Reward: 0.0
# Time Step:1244, Action: 2, Reward: 0.0
# Time Step:1245, Action: 3, Reward: 0.0
# Time Step:1246, Action: 2, Reward: 0.0
# Time Step:1247, Action: 1, Reward: 0.0
# Time Step:1248, Action: 2, Reward: 0.0
# Time Step:1249, Action: 2, Reward: 0.0
# Time Step:1250, Action: 2, Reward: 0.0
# Time Step:1251, Action: 3, Reward: 0.0
# Time Step:1252, Action: 2, Reward: 0.0
# Time Step:1253, Action: 2, Reward: 0.0
# Time Step:1254, Action: 2, Reward: 0.0
# Time Step:1255, Action: 0, Reward: 0.0
# Time Step:1256, Action: 3, Reward: 0.0
# ...
# Time Step:1610, Action: 3, Reward: 0.0
# Time Step:1611, Action: 3, Reward: 1.0
# Time Step:1612, Action: 3, Reward: 0.0
# Time Step:1613, Action: 1, Reward: 0.0
# Time Step:1614, Action: 1, Reward: 0.0
# Time Step:1615, Action: 0, Reward: 0.0
# Time Step:1616, Action: 0, Reward: 0.0
# Time Step:1617, Action: 0, Reward: 0.0
# Time Step:1618, Action: 0, Reward: 0.0
# Time Step:1619, Action: 2, Reward: 0.0
# Time Step:1620, Action: 3, Reward: 0.0
# Time Step:1621, Action: 3, Reward: 0.0
# Time Step:1622, Action: 2, Reward: 0.0
# Time Step:1623, Action: 3, Reward: 0.0
# Time Step:1624, Action: 0, Reward: 0.0
# Time Step:1625, Action: 0, Reward: 0.0
# Time Step:1626, Action: 2, Reward: 0.0
# Time Step:1627, Action: 2, Reward: 0.0
# Time Step:1628, Action: 2, Reward: 0.0
# Time Step:1629, Action: 0, Reward: 0.0
# Time Step:1630, Action: 2, Reward: 0.0
# Time Step:1631, Action: 0, Reward: 0.0
# Time Step:1632, Action: 2, Reward: 0.0
# Time Step:1633, Action: 0, Reward: 0.0
# Time Step:1634, Action: 0, Reward: 0.0
# Time Step:1635, Action: 1, Reward: 0.0
# Time Step:1636, Action: 3, Reward: 0.0
# Time Step:1637, Action: 1, Reward: 0.0
# Time Step:1638, Action: 1, Reward: 0.0
# Time Step:1639, Action: 0, Reward: 0.0
# Time Step:1640, Action: 1, Reward: 0.0
# Time Step:1641, Action: 3, Reward: 0.0
# Time Step:1642, Action: 3, Reward: 0.0
# Time Step:1643, Action: 3, Reward: 0.0
# Time Step:1644, Action: 3, Reward: 0.0
# Time Step:1645, Action: 3, Reward: 0.0
# Time Step:1646, Action: 3, Reward: 0.0
# Time Step:1647, Action: 3, Reward: 0.0
# Time Step:1648, Action: 2, Reward: 0.0
# Time Step:1649, Action: 2, Reward: 0.0
# Time Step:1650, Action: 3, Reward: 0.0
# Time Step:1651, Action: 3, Reward: 0.0
# Time Step:1652, Action: 3, Reward: 0.0
# Time Step:1653, Action: 3, Reward: 0.0
# Time Step:1654, Action: 3, Reward: 0.0
# Time Step:1655, Action: 3, Reward: 0.0
# Time Step:1656, Action: 3, Reward: 0.0
# Time Step:1657, Action: 3, Reward: 0.0
# Time Step:1658, Action: 2, Reward: 0.0
# Time Step:1659, Action: 2, Reward: 0.0
# Time Step:1660, Action: 3, Reward: 4.0
# Time Step:1661, Action: 0, Reward: 0.0
# Time Step:1662, Action: 0, Reward: 0.0
# Time Step:1663, Action: 0, Reward: 0.0
# Time Step:1664, Action: 0, Reward: 0.0
# Time Step:1665, Action: 0, Reward: 0.0
# Time Step:1666, Action: 3, Reward: 0.0
# Time Step:1667, Action: 3, Reward: 0.0
# Time Step:1668, Action: 0, Reward: 0.0
# Time Step:1669, Action: 2, Reward: 0.0
# Time Step:1670, Action: 2, Reward: 0.0
# Time Step:1671, Action: 3, Reward: 0.0
# Time Step:1672, Action: 3, Reward: 0.0
# Time Step:1673, Action: 3, Reward: 0.0
# Time Step:1674, Action: 3, Reward: 0.0
# Time Step:1675, Action: 2, Reward: 0.0
# Time Step:1676, Action: 2, Reward: 0.0
# Time Step:1677, Action: 2, Reward: 0.0
# Time Step:1678, Action: 2, Reward: 0.0
# Time Step:1679, Action: 2, Reward: 0.0
# Time Step:1680, Action: 2, Reward: 0.0
# Time Step:1681, Action: 3, Reward: 0.0
# Time Step:1682, Action: 3, Reward: 0.0
# Time Step:1683, Action: 0, Reward: 0.0
# Time Step:1684, Action: 2, Reward: 0.0
# Time Step:1685, Action: 3, Reward: 0.0
# Time Step:1686, Action: 3, Reward: 0.0
# Time Step:1687, Action: 2, Reward: 0.0
# Time Step:1688, Action: 2, Reward: 0.0
# Time Step:1689, Action: 3, Reward: 0.0
# Time Step:1690, Action: 3, Reward: 0.0
# Time Step:1691, Action: 2, Reward: 0.0
# Time Step:1692, Action: 3, Reward: 0.0
# Time Step:1693, Action: 2, Reward: 0.0
# Time Step:1694, Action: 2, Reward: 0.0
# Time Step:1695, Action: 2, Reward: 0.0
# Time Step:1696, Action: 0, Reward: 0.0
# Time Step:1697, Action: 2, Reward: 0.0
# Time Step:1698, Action: 3, Reward: 0.0
# Time Step:1699, Action: 1, Reward: 0.0
# Time Step:1700, Action: 1, Reward: 0.0
# Time Step:1701, Action: 3, Reward: 1.0
# Time Step:1702, Action: 0, Reward: 0.0
# Time Step:1703, Action: 0, Reward: 0.0
# Time Step:1704, Action: 0, Reward: 0.0
# Time Step:1705, Action: 0, Reward: 0.0
# Time Step:1706, Action: 3, Reward: 0.0
# Time Step:1707, Action: 0, Reward: 0.0
# Time Step:1708, Action: 3, Reward: 0.0
# Time Step:1709, Action: 1, Reward: 0.0
# Time Step:1710, Action: 3, Reward: 0.0
# Time Step:1711, Action: 2, Reward: 0.0
# Time Step:1712, Action: 2, Reward: 0.0
# Time Step:1713, Action: 2, Reward: 0.0
# Time Step:1714, Action: 0, Reward: 0.0
# Time Step:1715, Action: 2, Reward: 0.0
# Time Step:1716, Action: 2, Reward: 0.0
# Time Step:1717, Action: 2, Reward: 0.0
# Time Step:1718, Action: 2, Reward: 0.0
# Time Step:1719, Action: 0, Reward: 0.0
# Time Step:1720, Action: 0, Reward: 0.0
# Time Step:1721, Action: 0, Reward: 0.0
# Time Step:1722, Action: 0, Reward: 0.0
# Time Step:1723, Action: 0, Reward: 0.0
# Time Step:1724, Action: 0, Reward: 0.0
# Time Step:1725, Action: 0, Reward: 0.0
# Time Step:1726, Action: 0, Reward: 0.0
# Time Step:1727, Action: 0, Reward: 0.0
# Time Step:1728, Action: 0, Reward: 0.0
# Time Step:1729, Action: 0, Reward: 0.0
# Time Step:1730, Action: 0, Reward: 0.0
# Time Step:1731, Action: 0, Reward: 0.0
# Time Step:1732, Action: 0, Reward: 0.0
# Time Step:1733, Action: 0, Reward: 0.0
# Time Step:1734, Action: 2, Reward: 0.0
# Time Step:1735, Action: 0, Reward: 0.0
# Time Step:1736, Action: 0, Reward: 0.0
# Time Step:1737, Action: 1, Reward: 0.0
# Time Step:1738, Action: 0, Reward: 0.0
# Time Step:1739, Action: 3, Reward: 0.0
# Time Step:1740, Action: 0, Reward: 0.0
# Time Step:1741, Action: 2, Reward: 0.0
# Time Step:1742, Action: 2, Reward: 0.0
# Time Step:1743, Action: 2, Reward: 0.0
# Time Step:1744, Action: 3, Reward: 0.0
# Time Step:1745, Action: 1, Reward: 0.0
# Time Step:1746, Action: 1, Reward: 0.0
# Time Step:1747, Action: 3, Reward: 0.0
# Time Step:1748, Action: 2, Reward: 0.0
# Time Step:1749, Action: 1, Reward: 0.0
# Time Step:1750, Action: 2, Reward: 0.0
# Time Step:1751, Action: 2, Reward: 0.0
# Time Step:1752, Action: 2, Reward: 0.0
# Time Step:1753, Action: 2, Reward: 0.0
# Time Step:1754, Action: 2, Reward: 0.0
# Time Step:1755, Action: 2, Reward: 0.0
# Time Step:1756, Action: 2, Reward: 0.0
# Time Step:1757, Action: 2, Reward: 0.0
# Time Step:1758, Action: 2, Reward: 0.0
# Time Step:1759, Action: 0, Reward: 0.0
# Time Step:1760, Action: 1, Reward: 0.0
# Time Step:1761, Action: 2, Reward: 0.0
# Time Step:1762, Action: 3, Reward: 0.0
# Time Step:1763, Action: 3, Reward: 0.0
# Time Step:1764, Action: 3, Reward: 0.0
# Time Step:1765, Action: 3, Reward: 0.0
# Time Step:1766, Action: 3, Reward: 0.0
# Time Step:1767, Action: 3, Reward: 0.0
# Time Step:1768, Action: 3, Reward: 0.0
# Time Step:1769, Action: 3, Reward: 0.0
# Time Step:1770, Action: 3, Reward: 0.0
# Time Step:1771, Action: 1, Reward: 0.0
# Time Step:1772, Action: 1, Reward: 0.0
# Time Step:1773, Action: 1, Reward: 0.0
# Time Step:1774, Action: 1, Reward: 0.0
# Time Step:1775, Action: 1, Reward: 0.0
# Time Step:1776, Action: 1, Reward: 0.0
# Time Step:1777, Action: 1, Reward: 0.0
# Time Step:1778, Action: 2, Reward: 0.0
# Time Step:1779, Action: 1, Reward: 0.0
# Time Step:1780, Action: 2, Reward: 0.0
# Time Step:1781, Action: 2, Reward: 0.0
# Time Step:1782, Action: 2, Reward: 0.0
# Time Step:1783, Action: 1, Reward: 0.0
# Time Step:1784, Action: 2, Reward: 0.0
# Time Step:1785, Action: 3, Reward: 0.0
# Time Step:1786, Action: 3, Reward: 0.0
# Time Step:1787, Action: 1, Reward: 0.0
# Time Step:1788, Action: 3, Reward: 0.0
# Time Step:1789, Action: 1, Reward: 0.0
# Time Step:1790, Action: 3, Reward: 0.0
# Time Step:1791, Action: 3, Reward: 0.0
# Time Step:1792, Action: 3, Reward: 0.0
# Time Step:1793, Action: 3, Reward: 0.0
# Time Step:1794, Action: 3, Reward: 0.0
# Time Step:1795, Action: 3, Reward: 0.0
# Time Step:1796, Action: 3, Reward: 4.0
# Time Step:1797, Action: 0, Reward: 0.0
# Time Step:1798, Action: 2, Reward: 0.0
# Time Step:1799, Action: 2, Reward: 0.0
# Time Step:1800, Action: 0, Reward: 0.0
# Time Step:1801, Action: 2, Reward: 0.0
# Time Step:1802, Action: 0, Reward: 0.0
# Time Step:1803, Action: 0, Reward: 0.0
# Time Step:1804, Action: 3, Reward: 0.0
# Time Step:1805, Action: 3, Reward: 0.0
# Time Step:1806, Action: 1, Reward: 0.0
# Time Step:1807, Action: 0, Reward: 0.0
# Time Step:1808, Action: 0, Reward: 0.0
# Time Step:1809, Action: 0, Reward: 0.0
# Time Step:1810, Action: 0, Reward: 0.0
# Time Step:1811, Action: 0, Reward: 0.0
# Time Step:1812, Action: 0, Reward: 0.0
# Time Step:1813, Action: 1, Reward: 0.0
# Time Step:1814, Action: 0, Reward: 0.0
# Time Step:1815, Action: 2, Reward: 0.0
# Time Step:1816, Action: 3, Reward: 0.0
# Time Step:1817, Action: 1, Reward: 0.0
# Time Step:1818, Action: 1, Reward: 0.0
# Time Step:1819, Action: 1, Reward: 0.0
# Time Step:1820, Action: 3, Reward: 0.0
# Time Step:1821, Action: 2, Reward: 0.0
# Time Step:1822, Action: 2, Reward: 0.0
# Time Step:1823, Action: 2, Reward: 0.0
# Time Step:1824, Action: 2, Reward: 0.0
# Time Step:1825, Action: 2, Reward: 0.0
# Time Step:1826, Action: 2, Reward: 0.0
# Time Step:1827, Action: 2, Reward: 0.0
# Time Step:1828, Action: 2, Reward: 0.0
# Time Step:1829, Action: 0, Reward: 0.0
# Time Step:1830, Action: 0, Reward: 0.0
# Time Step:1831, Action: 1, Reward: 0.0
# Time Step:1832, Action: 3, Reward: 0.0
# Time Step:1833, Action: 3, Reward: 0.0
# Time Step:1834, Action: 2, Reward: 0.0
# Time Step:1835, Action: 2, Reward: 0.0
# Time Step:1836, Action: 2, Reward: 0.0
# Time Step:1837, Action: 2, Reward: 0.0
# Time Step:1838, Action: 2, Reward: 0.0
# Time Step:1839, Action: 2, Reward: 0.0
# Time Step:1840, Action: 2, Reward: 0.0
# Time Step:1841, Action: 2, Reward: 0.0
# Time Step:1842, Action: 2, Reward: 0.0
# Time Step:1843, Action: 3, Reward: 0.0
# Time Step:1844, Action: 3, Reward: 0.0
# Time Step:1845, Action: 1, Reward: 0.0
# Time Step:1846, Action: 3, Reward: 0.0
# Time Step:1847, Action: 0, Reward: 0.0
# Time Step:1848, Action: 0, Reward: 0.0
# Time Step:1849, Action: 0, Reward: 0.0
# Time Step:1850, Action: 0, Reward: 0.0
# Time Step:1851, Action: 0, Reward: 0.0
# Time Step:1852, Action: 1, Reward: 0.0
# Time Step:1853, Action: 0, Reward: 0.0
# Time Step:1854, Action: 0, Reward: 4.0
# Time Step:1855, Action: 3, Reward: 0.0
# Time Step:1856, Action: 0, Reward: 0.0
# Time Step:1857, Action: 0, Reward: 0.0
# Time Step:1858, Action: 0, Reward: 0.0
# Time Step:1859, Action: 0, Reward: 0.0
# Time Step:1860, Action: 3, Reward: 0.0
# Time Step:1861, Action: 3, Reward: 0.0
# Time Step:1862, Action: 3, Reward: 0.0
# Time Step:1863, Action: 3, Reward: 0.0
# Time Step:1864, Action: 3, Reward: 0.0
# Time Step:1865, Action: 3, Reward: 0.0
# Time Step:1866, Action: 0, Reward: 0.0
# Time Step:1867, Action: 3, Reward: 0.0
# Time Step:1868, Action: 0, Reward: 0.0
# Time Step:1869, Action: 0, Reward: 0.0
# Time Step:1870, Action: 0, Reward: 0.0
# Time Step:1871, Action: 0, Reward: 0.0
# Time Step:1872, Action: 3, Reward: 0.0
# Time Step:1873, Action: 3, Reward: 0.0
# Time Step:1874, Action: 3, Reward: 0.0
# Time Step:1875, Action: 0, Reward: 0.0
# Time Step:1876, Action: 1, Reward: 0.0
# Time Step:1877, Action: 2, Reward: 0.0
# Time Step:1878, Action: 2, Reward: 0.0
# Time Step:1879, Action: 0, Reward: 0.0
# Time Step:1880, Action: 2, Reward: 0.0
# Time Step:1881, Action: 1, Reward: 0.0
# Time Step:1882, Action: 3, Reward: 0.0
# Time Step:1883, Action: 1, Reward: 0.0
# Time Step:1884, Action: 1, Reward: 0.0
# Time Step:1885, Action: 2, Reward: 0.0
# Time Step:1886, Action: 2, Reward: 0.0
# Time Step:1887, Action: 2, Reward: 0.0
# Time Step:1888, Action: 1, Reward: 0.0
# Time Step:1889, Action: 3, Reward: 0.0
# Time Step:1890, Action: 3, Reward: 0.0
# Time Step:1891, Action: 3, Reward: 0.0
# Time Step:1892, Action: 3, Reward: 0.0
# Time Step:1893, Action: 3, Reward: 0.0
# Time Step:1894, Action: 2, Reward: 0.0
# Time Step:1895, Action: 2, Reward: 0.0
# Time Step:1896, Action: 3, Reward: 0.0
# Time Step:1897, Action: 3, Reward: 0.0
# Time Step:1898, Action: 2, Reward: 0.0
# Time Step:1899, Action: 3, Reward: 0.0
# Time Step:1900, Action: 1, Reward: 0.0
# Time Step:1901, Action: 1, Reward: 0.0
# Time Step:1902, Action: 3, Reward: 0.0
# Time Step:1903, Action: 3, Reward: 0.0
# Time Step:1904, Action: 3, Reward: 0.0
# Time Step:1905, Action: 3, Reward: 0.0
# Time Step:1906, Action: 3, Reward: 0.0
# Time Step:1907, Action: 3, Reward: 0.0
# Time Step:1908, Action: 3, Reward: 0.0
# Time Step:1909, Action: 0, Reward: 0.0
# Time Step:1910, Action: 2, Reward: 1.0
# Time Step:1911, Action: 0, Reward: 0.0
# Time Step:1912, Action: 0, Reward: 0.0
# Time Step:1913, Action: 3, Reward: 0.0
# Time Step:1914, Action: 3, Reward: 0.0
# Time Step:1915, Action: 3, Reward: 0.0
# Time Step:1916, Action: 0, Reward: 0.0
# Time Step:1917, Action: 0, Reward: 0.0
# Time Step:1918, Action: 0, Reward: 0.0
# Time Step:1919, Action: 1, Reward: 0.0
# Time Step:1920, Action: 3, Reward: 0.0
# Time Step:1921, Action: 3, Reward: 0.0
# Time Step:1922, Action: 0, Reward: 0.0
# Time Step:1923, Action: 0, Reward: 0.0
# Time Step:1924, Action: 0, Reward: 0.0
# Time Step:1925, Action: 2, Reward: 0.0
# Time Step:1926, Action: 3, Reward: 0.0
# Time Step:1927, Action: 3, Reward: 0.0
# Time Step:1928, Action: 3, Reward: 0.0
# Time Step:1929, Action: 0, Reward: 0.0
# Time Step:1930, Action: 2, Reward: 0.0
# Time Step:1931, Action: 0, Reward: 0.0
# Time Step:1932, Action: 3, Reward: 0.0
# Time Step:1933, Action: 3, Reward: 0.0
# Time Step:1934, Action: 3, Reward: 0.0
# Time Step:1935, Action: 3, Reward: 0.0
# Time Step:1936, Action: 2, Reward: 0.0
# Time Step:1937, Action: 0, Reward: 0.0
# Time Step:1938, Action: 2, Reward: 0.0
# Time Step:1939, Action: 2, Reward: 0.0
# Time Step:1940, Action: 1, Reward: 0.0
# Time Step:1941, Action: 0, Reward: 0.0
# Time Step:1942, Action: 0, Reward: 0.0
# Time Step:1943, Action: 0, Reward: 0.0
# Time Step:1944, Action: 0, Reward: 0.0
# Time Step:1945, Action: 0, Reward: 0.0
# Time Step:1946, Action: 0, Reward: 0.0
# Time Step:1947, Action: 0, Reward: 0.0
# Time Step:1948, Action: 0, Reward: 0.0
# Time Step:1949, Action: 0, Reward: 0.0
# Time Step:1950, Action: 0, Reward: 0.0
# Time Step:1951, Action: 0, Reward: -20
# time step: 1952, average reward: 15.0, episode: 1
# Time Step:1952, Action: 0, Reward: 0.0
# Time Step:1953, Action: 0, Reward: 0.0
# Time Step:1954, Action: 0, Reward: 0.0
# Time Step:1955, Action: 0, Reward: 0.0
# Time Step:1956, Action: 2, Reward: 0.0
# Time Step:1957, Action: 3, Reward: 0.0
# Time Step:1958, Action: 1, Reward: 0.0
# Time Step:1959, Action: 3, Reward: 0.0
# Time Step:1960, Action: 0, Reward: 0.0
# Time Step:1961, Action: 3, Reward: 0.0
# Time Step:1962, Action: 3, Reward: 0.0
# Time Step:1963, Action: 3, Reward: 0.0
# Time Step:1964, Action: 3, Reward: 0.0
# Time Step:1965, Action: 0, Reward: 0.0
# Time Step:1966, Action: 0, Reward: 0.0
# Time Step:1967, Action: 0, Reward: 0.0
# Time Step:1968, Action: 2, Reward: 0.0
# Time Step:1969, Action: 2, Reward: 0.0
# Time Step:1970, Action: 2, Reward: 0.0
# Time Step:1971, Action: 2, Reward: 0.0
# Time Step:1972, Action: 1, Reward: 0.0
# Time Step:1973, Action: 0, Reward: 0.0
# Time Step:1974, Action: 3, Reward: 0.0
# Time Step:1975, Action: 3, Reward: 0.0
# Time Step:1976, Action: 1, Reward: 0.0
# Time Step:1977, Action: 0, Reward: 0.0
# Time Step:1978, Action: 0, Reward: 0.0
# Time Step:1979, Action: 2, Reward: 0.0
# Time Step:1980, Action: 2, Reward: 0.0
# Time Step:1981, Action: 3, Reward: 0.0
# Time Step:1982, Action: 3, Reward: 0.0
# Time Step:1983, Action: 0, Reward: 0.0
# Time Step:1984, Action: 0, Reward: 0.0
# Time Step:1985, Action: 3, Reward: 0.0
# Time Step:1986, Action: 0, Reward: 0.0
# Time Step:1987, Action: 0, Reward: 0.0
# Time Step:1988, Action: 0, Reward: 0.0
# Time Step:1989, Action: 0, Reward: 0.0
# Time Step:1990, Action: 0, Reward: 0.0
# Time Step:1991, Action: 0, Reward: 0.0
# Time Step:1992, Action: 0, Reward: 0.0
# Time Step:1993, Action: 0, Reward: 0.0
# Time Step:1994, Action: 0, Reward: 0.0
# Time Step:1995, Action: 0, Reward: 0.0
# Time Step:1996, Action: 3, Reward: 0.0
# Time Step:1997, Action: 3, Reward: 0.0
# Time Step:1998, Action: 3, Reward: 0.0
# Time Step:1999, Action: 3, Reward: 0.0
# time step: 2858, average reward: -2.0, episode: 2
# time step: 3990, average reward: 7.0, episode: 3
# time step: 5126, average reward: 3.0, episode: 4
# time step: 5876, average reward: -7.0, episode: 5
# Exception ignored in: <function IteratorResourceDeleter.__del__ at 0x7f74fd42ee50>
# Traceback (most recent call last):
#   File "/home/himanshu/anaconda3/envs/project/lib/python3.8/site-packages/tensorflow/python/data/ops/iterator_ops.py", line 536, in __del__
#     gen_dataset_ops.delete_iterator(
#   File "/home/himanshu/anaconda3/envs/project/lib/python3.8/site-packages/tensorflow/python/ops/gen_dataset_ops.py", line 1277, in delete_iterator
#     _result = pywrap_tfe.TFE_Py_FastPathExecute(
# KeyboardInterrupt:

# %%
env.close()
